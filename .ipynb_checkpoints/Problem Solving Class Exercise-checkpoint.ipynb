# %% [markdown]
# # Problem 2

# %%
a = int(input("enter amount of fingers extended by Jane "))
b = int(input("enter amount of fingers extended by Jack "))
c = a + b
if c%2 == 0:
    print("even")
else:
    print("odd")
# Out:
# enter amount of fingers extended by Jane 2
# enter amount of fingers extended by Jack 4
# even

# %% [markdown]
# # Problem 3

# %%
RAND_SPEND = [165349.2, 167654.5, 156545.4, 155636.76, 132415.7, 134314.7, 123456.7, 163543.6, 132324.5, 164547.2]
Administration = [132434.5, 142452.6, 124335.6, 153426.7, 153437.8, 123234.8, 172436, 132223.78, 132324.66, 132324.56]
Marketing_Spend = [465768.8, 454536.7, 42331.4, 354628.67, 336644.86, 342415.86, 334422.5, 223314.6, 226781.9, 123256.5]
States = ["New York", "California", "Florida", "New York", "Florida", "New York", "California", "Florida", "New York", "California"]
Profit = [133243.4, 142325.5, 132245.8, 125623.8, 153425.7, 144325.9, 173421.6, 134324.5, 155324.5, 122332.5]

# %%
games = {"RAND_SPEND": RAND_SPEND , "Administration": Administration, "Marketing_Spend": Marketing_Spend, "States": States, "Profit": Profit}

# %%
games
# Out:
# {'RAND_SPEND': [165349.2,
#   167654.5,
#   156545.4,
#   155636.76,
#   132415.7,
#   134314.7,
#   123456.7,
#   163543.6,
#   132324.5,
#   164547.2],
#  'Administration': [132434.5,
#   142452.6,
#   124335.6,
#   153426.7,
#   153437.8,
#   123234.8,
#   172436,
#   132223.78,
#   132324.66,
#   132324.56],
#  'Marketing_Spend': [465768.8,
#   454536.7,
#   42331.4,
#   354628.67,
#   336644.86,
#   342415.86,
#   334422.5,
#   223314.6,
#   226781.9,
#   123256.5],
#  'States': ['New York',
#   'California',
#   'Florida',
#   'New York',
#   'Florida',
#   'New York',
#   'California',
#   'Florida',
#   'New York',
#   'California'],
#  'Profit': [133243.4,
#   142325.5,
#   132245.8,
#   125623.8,
#   153425.7,
#   144325.9,
#   173421.6,
#   134324.5,
#   155324.5,
#   122332.5]}

# %%
import pandas

# %%
dir(pandas)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_is_numpy_dev',
# ...

# %%
games = pandas.DataFrame(games)

# %%
games
# Out:
#    RAND_SPEND  Administration  Marketing_Spend      States    Profit
# 0   165349.20       132434.50        465768.80    New York  133243.4
# 1   167654.50       142452.60        454536.70  California  142325.5
# 2   156545.40       124335.60         42331.40     Florida  132245.8
# 3   155636.76       153426.70        354628.67    New York  125623.8
# 4   132415.70       153437.80        336644.86     Florida  153425.7
# 5   134314.70       123234.80        342415.86    New York  144325.9
# 6   123456.70       172436.00        334422.50  California  173421.6
# 7   163543.60       132223.78        223314.60     Florida  134324.5
# 8   132324.50       132324.66        226781.90    New York  155324.5
# 9   164547.20       132324.56        123256.50  California  122332.5

# %%
games.to_excel("games.xlsx")

# %% [markdown]
# # Problem 4

# %%
D = int(input("Enter distance the car has travelled "))
T = int(input("Enter time taken to reach distance D "))
